# %%
import pandas as pd

class RemoteWorkSurveyProcessor:
    def __init__(self, file_path):
        self.file_path = file_path
        self.df = None
        self.columns = [
            'ResponseId', 'MainBranch', 'Age', 'Country', 'EdLevel', 'WorkExp', 'CompTotal',
            'RemoteWork', 'Employment', 'OrgSize', 'JobSat', 'TimeSearching', 'TimeAnswering',
            'Frustration', 'SurveyLength', 'SurveyEase'
        ]
# Load dữ liệu
    def load_data(self):
        try:
            self.df = pd.read_csv(self.file_path)
            print("Dữ liệu đã được tải thành công.")
        except Exception as e:
            print(f"Lỗi khi tải dữ liệu: {e}")
# Làm sạch dữ liệu
    def clean_and_select_columns(self):
        if self.df is None:
            print("Dữ liệu chưa được tải.")
            return
        
        # Kiểm tra các cột bị thiếu
        missing_columns = [col for col in self.columns if col not in self.df.columns]
        if missing_columns:
            print(f"Các cột bị thiếu trong dữ liệu: {missing_columns}")
            print("Danh sách cột hiện tại:", self.df.columns.tolist())
            return

        self.df = self.df[self.columns].copy()
        self.df.dropna(inplace=True)
        print("Dữ liệu đã được làm sạch và chọn cột thành công.")

    def get_dataframe(self):
        return self.df
## Cách sử dựng class trên
file_path = "H:\\Dự án tốt nghiệp\\stack-overflow-developer-survey-2024\\survey_results_public.csv"

processor = RemoteWorkSurveyProcessor(file_path)
processor.load_data()
processor.clean_and_select_columns()

df_cleaned = processor.get_dataframe()
print(df_cleaned.head())
# Out:
# Dữ liệu đã được tải thành công.
# Dữ liệu đã được làm sạch và chọn cột thành công.
#      ResponseId                      MainBranch              Age  \
# 72           73  I am a developer by profession  18-24 years old
# 379         380  I am a developer by profession  35-44 years old
# 389         390  I am a developer by profession  25-34 years old
# 392         393  I am a developer by profession  35-44 years old
# 398         399  I am a developer by profession  45-54 years old
#
#                                                Country  \
# 72                                            Pakistan
# 379                                             Turkey
# 389                           United States of America
# 392  United Kingdom of Great Britain and Northern I...
# 398                           United States of America
#
#                                                EdLevel  WorkExp  CompTotal  \
# 72   Secondary school (e.g. American high school, G...      3.0  2040000.0
# 379    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)      7.0    85000.0
# 389  Some college/university study without earning ...      8.0   110000.0
# 392     Professional degree (JD, MD, Ph.D, Ed.D, etc.)     18.0   126420.0
# 398  Some college/university study without earning ...     30.0   195000.0
#
#                                RemoteWork  \
# 72   Hybrid (some remote, some in-person)
# 379                                Remote
# 389                                Remote
# 392  Hybrid (some remote, some in-person)
# 398                                Remote
#
#                                             Employment  \
# 72   Employed, full-time;Student, full-time;Indepen...
# 379                                Employed, full-time
# 389             Employed, full-time;Student, part-time
# 392                                Employed, full-time
# 398                                Employed, full-time
#
#                       OrgSize  JobSat               TimeSearching  \
# 72       100 to 499 employees    10.0         30-60 minutes a day
# 379        20 to 99 employees    10.0  Less than 15 minutes a day
# 389        10 to 19 employees    10.0        60-120 minutes a day
# 392  1,000 to 4,999 employees     7.0  Less than 15 minutes a day
# 398  1,000 to 4,999 employees     5.0         15-30 minutes a day
#
#                   TimeAnswering  \
# 72         60-120 minutes a day
# 379  Less than 15 minutes a day
# 389  Less than 15 minutes a day
# 392         30-60 minutes a day
# 398         15-30 minutes a day
#
#                                            Frustration           SurveyLength  \
# 72   Amount of technical debt;Number of software to...               Too long
# 379                 Complexity of tech stack for build               Too long
# 389   Number of software tools in use;Tracking my work               Too long
# 392  Amount of technical debt;Maintaining security ...  Appropriate in length
# 398  Amount of technical debt;Complexity of tech st...  Appropriate in length
#
#                      SurveyEase
# 72                         Easy
# 379                   Difficult
# 389                        Easy
# 392  Neither easy nor difficult
# 398                        Easy

# %%
df_cleaned.to_excel("du_lieu.xlsx", index=False, engine='openpyxl')
print("✅ Dữ liệu đã được lưu thành Excel tại: du_lieu_api.xlsx")
# Out:
# ✅ Dữ liệu đã được lưu thành Excel tại: du_lieu_api.xlsx
